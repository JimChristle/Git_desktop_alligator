# %%
import pandas as pd
import os
os.getcwd()
alligator= pd.read_csv("C:\\Users\\Jim/Downloads/fatal_alligator_attacks_US.csv", index_col=0)

# %%
print(alligator)
# Out:
#                                                  Name   Age     Sex  \
# Date
# August 15, 2022                          Nancy Becker    88  female
# July 15, 2022                      Rose Marie Wiegand   80s  female
# June 24, 2022                        Micheal Burstein    75    male
# May 31, 2022                          Sean McGuinness    47    male
# August 30, 2021                     Timothy Satterlee    71    male
# May 1, 2020                            Cynthia Covert    58  female
# August 20, 2018                       Cassandra Cline    45  female
# June 8, 2018                          Shizuka Matsuki    47  female
# July 29, 2016                           Bonnie Walker    90  female
# June 14, 2016                             Lane Graves     2    male
# on or about June 5, 2016       Richard Zachary Taylor    72    male
# on or about November 13, 2015         Matthew Riggins    22    male
# October 19, 2015                        James Okkerse    62    male
# ...

# %%
alligator.head()
# Out:
#                                 Name   Age     Sex  \
# Date
# August 15, 2022         Nancy Becker    88  female
# July 15, 2022     Rose Marie Wiegand   80s  female
# June 24, 2022       Micheal Burstein    75    male
# May 31, 2022         Sean McGuinness    47    male
# August 30, 2021    Timothy Satterlee    71    male
#
#                                                             Details
# Date
# August 15, 2022   The victim fell into a pond in a gated communi...
# July 15, 2022     The victim fell into a pond along a golf cours...
# June 24, 2022     The victim was dragged into a pond in Myrtle B...
# May 31, 2022      The victim was attacked while trying to retrie...
# August 30, 2021   The victim was attacked in floodwaters of Hurr...
